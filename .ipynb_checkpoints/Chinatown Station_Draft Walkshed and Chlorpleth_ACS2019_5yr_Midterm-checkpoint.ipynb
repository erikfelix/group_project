# %%
import pandas as pd

import geopandas as gpd

import contextily as ctx

import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
gdf = gpd.read_file('acs2019_5yr_B05015_14000US06037222001.geojson')

# %%
gdft = gpd.read_file('acs2019_5yr_B01003_14000US06037222001.geojson')

# %%
df = pd.merge(gdf, gdft)

# %%
df
# Out:
#                    geoid                                   name  B05015001  \
# 0           05000US06037                 Los Angeles County, CA  3430507.0
# 1     14000US06037101110  Census Tract 1011.10, Los Angeles, CA     1424.0
# 2     14000US06037101122  Census Tract 1011.22, Los Angeles, CA      810.0
# 3     14000US06037101210  Census Tract 1012.10, Los Angeles, CA     3167.0
# 4     14000US06037101220  Census Tract 1012.20, Los Angeles, CA     1749.0
# ...                  ...                                    ...        ...
# 2342  14000US06037980031  Census Tract 9800.31, Los Angeles, CA      146.0
# 2343  14000US06037980033  Census Tract 9800.33, Los Angeles, CA        0.0
# 2344  14000US06037990100     Census Tract 9901, Los Angeles, CA        0.0
# 2345  14000US06037990200     Census Tract 9902, Los Angeles, CA        0.0
# 2346  14000US06037990300     Census Tract 9903, Los Angeles, CA        0.0
#
#       B05015001, Error  B05015002  B05015002, Error  B05015003  \
# ...

# %%
df.to_json(r'/Users/kevin/Desktop\ACS_5_2019_Foreign_Total.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1335/1259313318.py in <module>
# ----> 1 df.to_json(r'/Users/kevin/Desktop\ACS_5_2019_Foreign_Total.json')
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in to_json(self, na, show_bbox, drop_id, **kwargs)
#     725         """
#     726         return json.dumps(
# --> 727             self._to_geo(na=na, show_bbox=show_bbox, drop_id=drop_id), **kwargs
#     728         )
#     729
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in _to_geo(self, **kwargs)
#     868         geo = {
#     869             "type": "FeatureCollection",
# --> 870             "features": list(self.iterfeatures(**kwargs)),
#     871         }
#     872
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in iterfeatures(self, na, show_bbox, drop_id)
#     800         """
# ...

# %%
df.to_json(r'/group_project/ACS_5_2019_Foreign_Total.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1335/2193219526.py in <module>
# ----> 1 df.to_json(r'/group_project/ACS_5_2019_Foreign_Total.json')
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in to_json(self, na, show_bbox, drop_id, **kwargs)
#     725         """
#     726         return json.dumps(
# --> 727             self._to_geo(na=na, show_bbox=show_bbox, drop_id=drop_id), **kwargs
#     728         )
#     729
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in _to_geo(self, **kwargs)
#     868         geo = {
#     869             "type": "FeatureCollection",
# --> 870             "features": list(self.iterfeatures(**kwargs)),
#     871         }
#     872
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in iterfeatures(self, na, show_bbox, drop_id)
#     800         """
# ...

# %%
df.to_json(r'/Users/kevin/Desktop/ACS_5_2019_Foreign_Total.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1335/3896299820.py in <module>
# ----> 1 df.to_json(r'/Users/kevin/Desktop/ACS_5_2019_Foreign_Total.json')
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in to_json(self, na, show_bbox, drop_id, **kwargs)
#     725         """
#     726         return json.dumps(
# --> 727             self._to_geo(na=na, show_bbox=show_bbox, drop_id=drop_id), **kwargs
#     728         )
#     729
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in _to_geo(self, **kwargs)
#     868         geo = {
#     869             "type": "FeatureCollection",
# --> 870             "features": list(self.iterfeatures(**kwargs)),
#     871         }
#     872
#
# /opt/conda/lib/python3.9/site-packages/geopandas/geodataframe.py in iterfeatures(self, na, show_bbox, drop_id)
#     800         """
# ...
